# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt

from msfm.utils import files

# %%
conf = "/global/u2/a/athomsen/multiprobe-simulation-forward-model/configs/v9/linear_bias.yaml"
conf = files.load_config(conf)

_, patches_pix_dict, _, _ = files.load_pixel_file(conf)
base_patch = patches_pix_dict["metacal"][0][0]
# Out:
# 24-08-06 07:41:59     files.py INF   Loaded the pixel file /global/u2/a/athomsen/multiprobe-simulation-forward-model/data/DESY3_pixels_v11_fiducial_512.h5

# %%
n_examples_per_cosmo = (
    conf["analysis"]["n_patches"]
    * conf["analysis"]["grid"]["n_perms_per_cosmo"]
    * conf["analysis"]["grid"]["n_noise_per_example"]
)
n_z = len(conf["survey"]["lensing"]["z_bins"] + conf["survey"]["clustering"]["z_bins"])

# %%
rng = np.random.default_rng()

# %%
# %timeit
samples = rng.standard_normal(
    size=(n_examples_per_cosmo, base_patch.size, n_z),
    dtype=np.float32
)

# %%
# noise_file = f"/pscratch/sd/a/athomsen/v11desy3/v9/linear_bias/cls/white_noise.h5"
noise_file = f"/pscratch/sd/a/athomsen/v11desy3/v9/linear_bias/cls/white_noise_0000.h5"

with h5py.File(noise_file, "r") as f:
    print(f.keys())
    cls = f["cls/raw"][:]
    
print(cls.shape)
# Out:
# <KeysViewHDF5 ['cls']>
# (240, 1536, 36)

# %%
cls.shape
# Out:
# (240, 1536, 36)

# %%
for i in range(10):
    plt.plot(cls[i*10,:,0])

# %%
with h5py.File("/pscratch/sd/a/athomsen/v11desy3/v9/linear_bias/cls/fiducial_cls.h5", "r") as f:
    print(f["cls/raw"].shape)
    cl_example = f["cls/raw"][0,:,0]
    
plt.plot(cl_example)
# Out:
# (40000, 1536, 36)

# %%
with h5py.File("/pscratch/sd/a/athomsen/temp.h5", "w") as f:
    f.create_dataset("test", shape=(10,10), dtype=np.float32)
    f.create_dataset("test", shape=(10,10), dtype=np.float32)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 with h5py.File("/pscratch/sd/a/athomsen/temp.h5", "w") as f:
#       2     f.create_dataset("test", shape=(10,10), dtype=np.float32)
# ----> 3     f.create_dataset("test", shape=(10,10), dtype=np.float32)
#
# File /global/common/software/des/athomsen/dlss/lib/python3.9/site-packages/h5py/_hl/group.py:161, in Group.create_dataset(self, name, shape, dtype, data, **kwds)
#     158         parent_path, name = name.rsplit(b'/', 1)
#     159         group = self.require_group(parent_path)
# --> 161 dsid = dataset.make_new_dset(group, shape, dtype, data, name, **kwds)
#     162 dset = dataset.Dataset(dsid)
#     163 return dset
#
# File /global/common/software/des/athomsen/dlss/lib/python3.9/site-packages/h5py/_hl/dataset.py:156, in make_new_dset(parent, shape, dtype, data, name, chunks, compression, shuffle, fletcher32, maxshape, compression_opts, fillvalue, scaleoffset, track_times, external, track_order, dcpl, dapl, efile_prefix, virtual_prefix, allow_unknown_filter)
#     152 else:
#     153     sid = h5s.create_simple(shape, maxshape)
# --> 156 dset_id = h5d.create(parent.id, name, tid, sid, dcpl=dcpl, dapl=dapl)
#     158 if (data is not None) and (not isinstance(data, Empty)):
#     159     dset_id.write(h5s.ALL, h5s.ALL, data)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5d.pyx:87, in h5py.h5d.create()
#
# ValueError: Unable to create dataset (name already exists)
